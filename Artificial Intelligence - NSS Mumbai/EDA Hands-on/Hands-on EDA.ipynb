# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# In this Book we will be using Covid-19 dataset to perform EDA, the dataset file is given in csv format on the github.

# %%
#As previously stated in the post on Mighty Networks we will be using packages 
#Below are the packages and syntax to import them, we will call these packages using import method
#Importing libraries
import numpy as np
print("Imported Numpy as np")
import pandas as pd
print("Imported pandas as pd")
import matplotlib.pyplot as plt
print("Imported matplotlib.pyplot as plt")

#Print statement lets you vizualize your modules getting imported
# Out:
# Imported Numpy as np
# Imported pandas as pd
# Imported matplotlib.pyplot as plt

# %%
#Calling and Visualizing the data
#Here we will call the dataset and vizualize it using pandas dataframe
#We will assign some variable "Data"

Data = pd.read_csv("country_wise_latest.csv")
Data

#To read csv we data we use the dot(.) function pd.read_csv and call the variable data to showcase the dataset as below
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#We will check the size of dataset using .shape function
Data.shape
# Out:
# (187, 15)

# %%
#To check the type of dataframe used we use type(variable name)
type(Data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Moving ahead we will lookout for missing values in the dataset 
#Missing data, or missing values, occur when you don't have data stored for certain variables or participants. 
#Data can go missing due to incomplete data entry, equipment malfunctions, lost files, and many other reasons. 
#In any dataset, there are usually some missing data

#Checking For Missing Values in all the column and sum up the missing value
Data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# With The results above you can see there is no missing values in the dataset.

# %%
#Check for the data type of each attribute
#This tell us what kind of data type each column holds 
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %% [markdown]
# If there were any kind of null data present in the dataset we would have to replace the null value using .mean method
# in that particular column.

# %%
#Asking Analytical Questions and Visualizations
#We will now look out for correlation between the column. 
#Correlation coefficients are used to measure the strength of the relationship between two variables. 
#Pearson correlation is the one most commonly used in statistics. 
#This measures the strength and direction of a linear relationship between two variables.

#Here we will use seaborn to plot heatmap of correlation. 
import seaborn as sns
print("Imported Seaborn as sns")
print("Plotting Correlation Heatmap")
plt.figure(figsize=(10,10))
sns.heatmap(Data.corr(),cbar=True,annot= True,cmap='Blues')
# Out:
# Imported Seaborn as sns
# Plotting Correlation Heatmap
# <AxesSubplot:>

# %% [markdown]
# Note:
# -1 indicates a perfectly negative linear correlation between two variables.
#
# 0 indicates no linear correlation between two variables.
#
# 1 indicates a perfectly positive linear correlation between two variables.
#
# In above Matrix:
#
# Notice that the correlation coefficients along the diagonal of the table are all equal to 1 because each variable is perfectly correlated with itself.
#
# These cells aren’t useful for interpretation.
#
# Number below -0.968 Large negative correlation (which are not useful for us)
#
# Number 0 is referred as No correlation (No use)
#
# Number above 0.47 have Moderate positive correlation (may or maynot be useful)
#
# Number above 0.93 have Large positive correlation (Highly useful correlation)
#
# For more info on correlation refer this site:
#
# https://support.minitab.com/en-us/minitab-express/1/help-and-how-to/modeling-statistics/regression/how-to/correlation/interpret-the-results/

# %% [raw]
# Now According to what relation we want to find we use those variable and move ahead with algorithm implementation
